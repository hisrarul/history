# %% [markdown]
# #### Problem statement
#
# What customer segments are more likely to churn balances in the next quarter by at least 50% considering current quarter?

# %% [markdown]
# #### Data sources
#
# We collect data from different databases of the bank such as
#
# * Customer demographic e.g cust are from rural, urban or gender, etc.
# * Transaction Data e.g credit amount, assets and liability, etc.
# * Bank Branch data e.g customer offline interaction

# %% [markdown]
# #### References
# * https://www.analyticsvidhya.com/blog/2022/03/an-overview-of-data-collection-data-sources-and-data-mining/
